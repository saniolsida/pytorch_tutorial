# %%
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader

from matplotlib.pyplot import imshow

# %%
matplotlib inline

# %%
trans = transforms.Compose([
    tansforms.Resize((64,128))
])

train_data = torchvision.datasets.ImageFolder(root='custom_data/origin_data', transform=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 trans = transforms.Compose([
# ----> 2     tansforms.Resize((64,128))
#       3 ])
#       4
#       5 train_data = torchvision.datasets.ImageFolder(root='custom_data/origin_data', transform=None)
#
# NameError: name 'tansforms' is not defined

# %%
for num, value in enumerate(train_data):
    data, label = value
    print(num, data, label)

    if(label ==0):
        data.save('custom_data/train_data/gray/%d_%d.jpeg',%(num, label))
    else:
        data.save('custom_data/train_data/red/%d_%d.jpeg',%(num, label))
# Out:
# 0 <PIL.Image.Image image mode=RGB size=512x256 at 0x1143713D0> 0
